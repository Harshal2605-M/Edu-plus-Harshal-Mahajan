# %%
#1
students = {"Aditya" : 90, "Harshal" : 30, "Yash" :96, "Prajwal" : 80, "Durgesh":60}
print(students)
# Out:
# {'Aditya': 90, 'Harshal': 30, 'Yash': 96, 'Prajwal': 80, 'Durgesh': 60}

# %%
#2
print(students["Yash"])
# Out:
# 96

# %%
#3
students["Atharv"] = 76
print(students)
# Out:
# {'Aditya': 90, 'Harshal': 30, 'Yash': 96, 'Prajwal': 80, 'Durgesh': 60, 'Atharv': 76}

# %%
#4
students["Durgesh"] = 68
print(students)
# Out:
# {'Aditya': 90, 'Harshal': 30, 'Yash': 96, 'Prajwal': 80, 'Durgesh': 68, 'Atharv': 76}

# %%
#5
del students["Durgesh"]
print(students)
# Out:
# {'Aditya': 90, 'Harshal': 30, 'Yash': 96, 'Prajwal': 80, 'Atharv': 76}

# %%
#6
print(students.keys())
# Out:
# dict_keys(['Aditya', 'Harshal', 'Yash', 'Prajwal', 'Atharv'])

# %%
#7
print(students.values())
# Out:
# dict_values([90, 30, 96, 80, 76])

# %%
#8
print(students.items())
# Out:
# dict_items([('Aditya', 90), ('Harshal', 30), ('Yash', 96), ('Prajwal', 80), ('Atharv', 76)])

# %%
#9
print("Yash" in students.keys())
# Out:
# True

# %%
#10
print(90 in students.values())
# Out:
# True

# %%
#11
students.get("Harshal")
# Out:
# 30

# %%
#12
employees = {
    "Yash": "Human Resources",
    "Harshal": "Engineering",
    "Prajwal": "Marketing",
    "Durgesh": "Finance",
    "Atharav": "Sales"
}

# %%
#13
print(employees["Yash"])
# Out:
# Human Resources

# %%
#14
employees["Rudraksha"] = "Desining"
print(employees)
# Out:
# {'Yash': 'Human Resources', 'Harshal': 'Engineering', 'Prajwal': 'Marketing', 'Durgesh': 'Finance', 'Atharav': 'Sales', 'Rudraksha': 'Desining'}

# %%
#15
employees["Rudraksha"] = "Testing"
print(employees)
# Out:
# {'Yash': 'Human Resources', 'Harshal': 'Engineering', 'Prajwal': 'Marketing', 'Durgesh': 'Finance', 'Atharav': 'Sales', 'Rudraksha': 'Testing'}

# %%
#16
del employees["Rudraksha"]
print(employees)
# Out:
# {'Yash': 'Human Resources', 'Harshal': 'Engineering', 'Prajwal': 'Marketing', 'Durgesh': 'Finance', 'Atharav': 'Sales'}

# %%
#17
sort_dic = dict(sorted(employees.items()))
print(sort_dic)
# Out:
# {'Atharav': 'Sales', 'Durgesh': 'Finance', 'Harshal': 'Engineering', 'Prajwal': 'Marketing', 'Yash': 'Human Resources'}

# %%
#18
sort_dic_dept = dict(sorted(employees.items(), key = lambda a : a[1]))
print(sort_dic_dept)
# Out:
# {'Harshal': 'Engineering', 'Durgesh': 'Finance', 'Yash': 'Human Resources', 'Prajwal': 'Marketing', 'Atharav': 'Sales'}

# %%
#19
sort_dic = dict(sorted(employees.items(), reverse = True))
print(sort_dic)
# Out:
# {'Yash': 'Human Resources', 'Prajwal': 'Marketing', 'Harshal': 'Engineering', 'Durgesh': 'Finance', 'Atharav': 'Sales'}

# %%
#20
sort_dic_dept = dict(sorted(employees.items(), key = lambda a : a[1], reverse = True))
print(sort_dic_dept)
# Out:
# {'Atharav': 'Sales', 'Prajwal': 'Marketing', 'Yash': 'Human Resources', 'Durgesh': 'Finance', 'Harshal': 'Engineering'}

# %%
#21
for key, value in employees.items():
    if(value == "Sales"):
        print(key)
# Out:
# Atharav

# %%
#22
for key, value in students.items():
    if(value > 80):
        print(key)
# Out:
# Aditya
# Yash

# %%
#23
students = {
    "Harshal": {
        "age": 20,
        "grade": "A",
        "department": "Computer Science"
    },
    "Durgesh": {
        "age": 21,
        "grade": "B+",
        "department": "Mechanical Engineering"
    },
    "Yash": {
        "age": 19,
        "grade": "A-",
        "department": "Electrical Engineering"
    }
}
print(students)
# Out:
# {'Harshal': {'age': 20, 'grade': 'A', 'department': 'Computer Science'}, 'Durgesh': {'age': 21, 'grade': 'B+', 'department': 'Mechanical Engineering'}, 'Yash': {'age': 19, 'grade': 'A-', 'department': 'Electrical Engineering'}}

# %%
#24
grade = students["Harshal"]["grade"]
print(grade)
# Out:
# A

# %%
#25
